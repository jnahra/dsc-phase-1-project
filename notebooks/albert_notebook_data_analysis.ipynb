# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('masterdataset.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         1459 non-null   int64
#  1   id                 1459 non-null   int64
#  2   release_date       1459 non-null   object
#  3   movie              1459 non-null   object
#  4   production_budget  1459 non-null   object
#  5   domestic_gross     1459 non-null   object
#  6   worldwide_gross    1459 non-null   object
#  7   year               1459 non-null   int64
#  8   movie_id           1459 non-null   object
#  9   original_title     1459 non-null   object
#  10  runtime_minutes    1459 non-null   float64
#  11  genres             1459 non-null   object
#  12  averagerating      1459 non-null   float64
#  13  numvotes           1459 non-null   float64
# dtypes: float64(3), int64(3), object(8)
# memory usage: 159.7+ KB

# %%
# change the monetary values into integers 'worldwide_gross' 'domestic_gross' 'production_budget'

df['worldwide_gross'] = df['worldwide_gross'].str[1:]

df['worldwide_gross'] = df['worldwide_gross'].str.replace(',','')

df['worldwide_gross'] = df['worldwide_gross'].astype(int)

df['domestic_gross'] = df['domestic_gross'].str[1:]

df['domestic_gross'] = df['domestic_gross'].str.replace(',','')

df['domestic_gross'] = df['domestic_gross'].astype(int)

df['production_budget'] = df['production_budget'].str[1:]

df['production_budget'] = df['production_budget'].str.replace(',','')

df['production_budget'] = df['production_budget'].astype(int)

df['profit'] = df['worldwide_gross'] - df['production_budget']

df['ROI'] = df['profit'] / df['production_budget'] * 100

# %%
df
# Out:
#       Unnamed: 0  id  release_date  \
# 0              0   2  May 20, 2011
# 1              1   3   Jun 7, 2019
# 2              2   4   May 1, 2015
# 3              3   7  Apr 27, 2018
# 4              4   9  Nov 17, 2017
# ...          ...  ..           ...
# 1454        1541  45  Jan 27, 2017
# 1455        1542  49   Sep 1, 2015
# 1456        1544  52   Dec 1, 2015
# 1457        1545  59  Nov 25, 2011
# 1458        1546  62  Dec 31, 2014
#
#                                             movie  production_budget  \
# 0     Pirates of the Caribbean: On Stranger Tides          410600000
# 1                                    Dark Phoenix          350000000
# 2                         Avengers: Age of Ultron          330600000
# 3                          Avengers: Infinity War          300000000
# 4                                  Justice League          300000000
# ...                                           ...                ...
# ...

# %%
df_filtered = df[(df['production_budget'] >= 10000000) & (df['runtime_minutes'] >= 75) & (df['numvotes'] >= 1000)]

# %%
df_filtered
# Out:
#       Unnamed: 0  id  release_date  \
# 0              0   2  May 20, 2011
# 1              1   3   Jun 7, 2019
# 2              2   4   May 1, 2015
# 3              3   7  Apr 27, 2018
# 4              4   9  Nov 17, 2017
# ...          ...  ..           ...
# 1055        1108  32  Dec 26, 2014
# 1056        1109  33  Dec 31, 2010
# 1057        1110  36   Oct 8, 2010
# 1058        1111  39  Sep 26, 2014
# 1059        1113  47  May 19, 2015
#
#                                             movie  production_budget  \
# 0     Pirates of the Caribbean: On Stranger Tides          410600000
# 1                                    Dark Phoenix          350000000
# 2                         Avengers: Age of Ultron          330600000
# 3                          Avengers: Infinity War          300000000
# 4                                  Justice League          300000000
# ...                                           ...                ...
# ...

# %%
df_filtered.sort_values(by='ROI', ascending = False)
# Out:
#       Unnamed: 0  id  release_date                   movie  production_budget  \
# 961         1008  43   Jun 6, 2014  The Fault in Our Stars           12000000
# 1005        1054  36  Oct 19, 2018               Halloween           10000000
# 937          981  46   Dec 3, 2010              Black Swan           13000000
# 765          799  92   Dec 9, 2016              La La Land           20000000
# 890          934   2  Aug 11, 2017     Annabelle: Creation           15000000
# ...          ...  ..           ...                     ...                ...
# 243          256  80  Dec 13, 2017                  Bright           90000000
# 356          370  52  Dec 11, 2015        The Ridiculous 6           60000000
# 990         1038  54   Oct 3, 2014              Drive Hard           12000000
# 763          797  82   Feb 1, 2019          Velvet Buzzsaw           21000000
# 1059        1113  47  May 19, 2015   Into the Grizzly Maze           10000000
#
# ...

# %%
# Want to determine which years are part of our dataset
sorted(df_filtered['year'].unique())
# Out:
# [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019]

# %%
df_filtered[df_filtered['movie'].str.contains('Resident Evil')]
# Out:
#      Unnamed: 0  id  release_date                       movie  \
# 322         336   4  Sep 14, 2012  Resident Evil: Retribution
# 365         380  70  Sep 10, 2010    Resident Evil: Afterlife
#
#      production_budget  domestic_gross  worldwide_gross  year   movie_id  \
# 322           65000000        42345531        240647629  2012  tt1855325
# 365           57500000        60128566        295874190  2010  tt1220634
#
#                  original_title  runtime_minutes                   genres  \
# 322  Resident Evil: Retribution             95.0     Action,Horror,Sci-Fi
# 365    Resident Evil: Afterlife             96.0  Action,Adventure,Horror
#
#      averagerating  numvotes     profit         ROI
# 322            5.4  125191.0  175647629  270.227122
# 365            5.9  153270.0  238374190  414.563809

# %%
# Resident Evil Retribution and Afterlife 270 and 414.5 ROI, Need for Speed 194 ROI, Hitman: Agent 47 ROI 135
# Warcraft 166 ROI, Tomb Raider 204 ROI, Rampage 257 ROI

# %%
videogames = ['Resident Evil: Retribution', 'Resident Evil: Afterlife', 'Need for Speed', 'Hitman: Agent 47', 'Warcraft', 'Tomb Raider', 'Rampage']

# %%
videogame_movies = df_filtered[df_filtered['movie'].isin(videogames)]
videogame_movies
# Out:
#      Unnamed: 0  id  release_date                       movie  \
# 100         102  46  Jun 10, 2016                    Warcraft
# 171         176  90  Apr 13, 2018                     Rampage
# 238         248  70  Mar 16, 2018                 Tomb Raider
# 311         325  70  Mar 14, 2014              Need for Speed
# 322         336   4  Sep 14, 2012  Resident Evil: Retribution
# 365         380  70  Sep 10, 2010    Resident Evil: Afterlife
# 563         585   8  Aug 21, 2015            Hitman: Agent 47
#
#      production_budget  domestic_gross  worldwide_gross  year   movie_id  \
# 100          160000000        47225655        425522281  2016  tt0803096
# 171          120000000       101028233        428056280  2018  tt2231461
# 238           90000000        58250803        273477501  2018  tt1365519
# 311           66000000        43568507        194169619  2014  tt2369135
# 322           65000000        42345531        240647629  2012  tt1855325
# ...

# %%
videogame_movies = videogame_movies.drop('original_title', axis = 1)

# %%
videogame_movies = videogame_movies.sort_values(by = 'release_date', ascending = False)

# %%
videogame_movies.to_csv('videogame_movies.csv')

# %%
# !ls
# Out:
# CONTRIBUTING.md                     moviegenres.jpeg
# LICENSE.md                          moviegenres.pdf
# README.md                           moviegenres.png
# albert_notebook_data_analysis.ipynb student.ipynb
# albert_phase1_notebook.ipynb        videogame_movies.csv
# awesome.gif                         videogame_movies.xlsx
# masterdataset.csv                   zippedData
# masterdatasetdraft.csv              ~$videogame_movies.xlsx
# movie_data_erd.jpeg

# %%
# Created scatter plot showing rating vs. ROI

sns.scatterplot(x = df_filtered['averagerating'], y = df_filtered['ROI'])
plt.xlabel('Average Rating')
plt.ylabel('ROI')
plt.title('Average Rating vs. ROI')
ax.ticklabel_format(useOffset=False)
plt.ticklabel_format(axis = 'x', style='plain')

plt.show;

plt.savefig('ratingvsroi.jpeg')

# %%
# !ls
# Out:
# CONTRIBUTING.md                     moviegenres.jpeg
# LICENSE.md                          moviegenres.pdf
# README.md                           moviegenres.png
# albert_notebook_data_analysis.ipynb ratingvsroi.pdf
# albert_phase1_notebook.ipynb        student.ipynb
# awesome.gif                         videogame_movies.csv
# masterdataset.csv                   videogame_movies.xlsx
# masterdatasetdraft.csv              zippedData
# movie_data_erd.jpeg                 ~$videogame_movies.xlsx

# %%
# Created scatter plot of runtime vs. ROI

sns.scatterplot(x = df_filtered['runtime_minutes'], y = df_filtered['ROI'])
plt.xlabel('Runtime (minutes)')
plt.ylabel('ROI')
plt.title('Runtime vs. ROI')
ax.ticklabel_format(useOffset=False)
plt.ticklabel_format(axis = 'x', style='plain')

plt.show;

plt.savefig('runtimevsroi.jpeg')

# %%
# Created scatter plot of budget vs. ROI
sns.scatterplot(x = df_filtered['production_budget'], y = df_filtered['ROI'])
plt.xlabel('Budget ($)')
plt.ylabel('ROI')
plt.title('Production Budget vs. ROI')
ax.ticklabel_format(useOffset=False)
plt.ticklabel_format(axis = 'x', style='plain')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show;

plt.savefig('productionbudgetvsroi.jpeg')
