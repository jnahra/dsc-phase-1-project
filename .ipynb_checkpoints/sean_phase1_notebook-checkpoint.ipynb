# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Student name:
# * Student pace: self paced / part time / full time
# * Scheduled project review date/time:
# * Instructor name:
# * Blog post URL:

# %%
# Your code here - remember to use markdown cells for comments as well!

# %%
import pandas as pd
import gzip
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from IPython.display import Image
Image(filename='movie_data_erd.jpeg')

# %%
master = pd.read_csv('masterdataset.csv')
master.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         1459 non-null   int64
#  1   id                 1459 non-null   int64
#  2   release_date       1459 non-null   object
#  3   movie              1459 non-null   object
#  4   production_budget  1459 non-null   object
#  5   domestic_gross     1459 non-null   object
#  6   worldwide_gross    1459 non-null   object
#  7   year               1459 non-null   int64
#  8   movie_id           1459 non-null   object
#  9   original_title     1459 non-null   object
#  10  runtime_minutes    1459 non-null   float64
#  11  genres             1459 non-null   object
#  12  averagerating      1459 non-null   float64
#  13  numvotes           1459 non-null   float64
# dtypes: float64(3), int64(3), object(8)
# memory usage: 159.7+ KB

# %%
master['numvotes'] #drop extra
# Out:
# 0       447624.0
# 1        24451.0
# 2       665594.0
# 3       670926.0
# 4       329135.0
#           ...
# 1454        13.0
# 1455      5156.0
# 1456        82.0
# 1457       127.0
# 1458        85.0
# Name: numvotes, Length: 1459, dtype: float64

# %%
master['genres'].value_counts()
# Out:
# Adventure,Animation,Comedy    67
# Comedy                        53
# Action,Adventure,Sci-Fi       52
# Comedy,Drama,Romance          51
# Drama                         50
#                               ..
# Fantasy,Horror,Thriller        1
# Comedy,Drama,Horror            1
# Biography,Drama,Mystery        1
# Biography,Family,Sport         1
# Comedy,Drama,Mystery           1
# Name: genres, Length: 226, dtype: int64

# %%
master['worldwide_gross']
# Out:
# 0       $1,045,663,875
# 1         $149,762,350
# 2       $1,403,013,963
# 3       $2,048,134,200
# 4         $655,945,209
#              ...
# 1454            $3,547
# 1455          $489,792
# 1456                $0
# 1457                $0
# 1458                $0
# Name: worldwide_gross, Length: 1459, dtype: object

# %%
master['worldwide_gross'] = master['worldwide_gross'].str[1:]

# %%
master['worldwide_gross'] = master['worldwide_gross'].str.replace(',','')

# %%
master['worldwide_gross'] = master['worldwide_gross'].astype(int)

# %%
master['production_budget'] = master['production_budget'].str[1:]

# %%
master['production_budget'] = master['production_budget'].str.replace(',','')

# %%
master['production_budget'] = master['production_budget'].astype(int)

# %%
master['profit'] = master['worldwide_gross'] - master['production_budget']

# %%
master.sort_values('profit',ascending=False)
# Out:
#      Unnamed: 0  id  release_date                   movie  production_budget  \
# 3             3   7  Apr 27, 2018  Avengers: Infinity War          300000000
# 23           23  34  Jun 12, 2015          Jurassic World          215000000
# 45           46  67   Apr 3, 2015               Furious 7          190000000
# 18           18  27   May 4, 2012            The Avengers          225000000
# 27           27  42  Feb 16, 2018           Black Panther          200000000
# ..          ...  ..           ...                     ...                ...
# 242         255  79  Nov 24, 2010    The Nutcracker in 3D           90000000
# 241         253  78  Apr 21, 2017             The Promise           90000000
# 243         256  80  Dec 13, 2017                  Bright           90000000
# 122         124  94  Mar 11, 2011         Mars Needs Moms          150000000
# 1             1   3   Jun 7, 2019            Dark Phoenix          350000000
#
#     domestic_gross  worldwide_gross  year   movie_id          original_title  \
# 3     $678,815,482       2048134200  2018  tt4154756  Avengers: Infinity War
# 23    $652,270,625       1648854864  2015  tt0369610          Jurassic World
# 45    $353,007,020       1518722794  2015  tt2820852           Furious Seven
# 18    $623,279,547       1517935897  2012  tt0848228            The Avengers
# 27    $700,059,566       1348258224  2018  tt1825683           Black Panther
# ..             ...              ...   ...        ...                     ...
# 242       $195,459         20466016  2010  tt1041804    The Nutcracker in 3D
# 241     $8,224,288         10551417  2017  tt7232438         Puen Tee Raluek
# 243             $0                0  2017  tt5519340                  Bright
# 122    $21,392,758         39549758  2011  tt1305591         Mars Needs Moms
# 1      $42,762,350        149762350  2019  tt6565702            Dark Phoenix
#
#      runtime_minutes                      genres  averagerating   numvotes  \
# 3              149.0     Action,Adventure,Sci-Fi            8.5   670926.0
# 23             124.0     Action,Adventure,Sci-Fi            7.0   539338.0
# 45             137.0       Action,Crime,Thriller            7.2   335074.0
# 18             143.0     Action,Adventure,Sci-Fi            8.1  1183655.0
# 27             134.0     Action,Adventure,Sci-Fi            7.3   516148.0
# ..               ...                         ...            ...        ...
# 242            110.0       Action,Family,Fantasy            4.3     3119.0
# 241            114.0       Drama,Horror,Thriller            6.1      629.0
# 243            117.0        Action,Crime,Fantasy            6.4   147834.0
# 122             88.0  Adventure,Animation,Family            5.4    19823.0
# 1              113.0     Action,Adventure,Sci-Fi            6.0    24451.0
#
#          profit
# 3    1748134200
# 23   1433854864
# 45   1328722794
# 18   1292935897
# 27   1148258224
# ..          ...
# 242   -69533984
# 241   -79448583
# 243   -90000000
# 122  -110450242
# 1    -200237650
#
# [1459 rows x 15 columns]

# %%
master['ROI'] = master['profit'] / master['production_budget'] * 100

# %%
master.sort_values('ROI',ascending=False)[0:50]
# Out:
#       Unnamed: 0  id  release_date                                 movie  \
# 1436        1521  80  Jul 10, 2015                           The Gallows
# 1349        1423  12   Jan 6, 2012                      The Devil Inside
# 1237        1303  65  Oct 20, 2010                 Paranormal Activity 2
# 1151        1208  49  Feb 24, 2017                               Get Out
# 1325        1398  64  Oct 21, 2016                             Moonlight
# 1350        1424  18  May 25, 2012                     Chernobyl Diaries
# 1152        1209  51  Oct 21, 2011                 Paranormal Activity 3
# 1126        1182  84   Oct 3, 2014                             Annabelle
# 1316        1389  15  Aug 27, 2010                     The Last Exorcism
# 1062        1116  56  Dec 21, 2016                                Dangal
# 1239        1305  67   Jun 7, 2013                             The Purge
# 1154        1211  55  Jul 22, 2016                            Lights Out
# 1240        1306  69  Oct 12, 2012                              Sinister
# 1157        1215  59  Oct 19, 2012                 Paranormal Activity 4
# 1437        1522  86   Jul 7, 2017                         A Ghost Story
# 1226        1290  91  Apr 13, 2018                         Truth or Dare
# 961         1008  43   Jun 6, 2014                The Fault in Our Stars
# 1005        1054  36  Oct 19, 2018                             Halloween
# 937          981  46   Dec 3, 2010                            Black Swan
# 1156        1214  58  Oct 13, 2017                       Happy Death Day
# 1238        1304  66  Aug 28, 2015                              War Room
# 1108        1163  88  Jun 29, 2012                            Magic Mike
# 1265        1334  12  Jan 11, 2013                       A Haunted House
# 1153        1210  54  Mar 11, 2016                   10 Cloverfield Lane
# 765          799  92   Dec 9, 2016                            La La Land
# 1158        1216  60  Oct 24, 2014                                 Ouija
# 890          934   2  Aug 11, 2017                   Annabelle: Creation
# 537          558  24   Sep 8, 2017                                    It
# 1155        1213  56  Sep 11, 2015                             The Visit
# 867          909  66   Apr 6, 2018                         A Quiet Place
# 1455        1542  49   Sep 1, 2015                                Exeter
# 1211   1331.826225
# 465    1327.495252
# 734    1300.149735
# 359    1281.078609
# 279    1279.637000
# 1210   1235.048450

# %%
master['ROI'].describe()
# Out:
# count    1050.000000
# mean      213.573901
# std       310.786432
# min      -100.000000
# 25%        19.899827
# 50%       137.007215
# 75%       300.122751
# max      2459.723617
# Name: ROI, dtype: float64

# %% [markdown]
# Dropping certain values from certain columns to specify the results for visualization

# %% [markdown]
# These values we are dropping include:
#
# runtime_minutes below 75.0
#
# production_budget below $10,000,000
#
# numvotes below 1000

# %%
master = master[master['runtime_minutes'] >= 75.0]

# %%
master = master[master['production_budget'] >= 10000000]

# %%
master = master[master['numvotes'] >= 1000]

# %%
sns.scatterplot(x='runtime_minutes', y='averagerating', data=master)
plt.title('Runtime vs. Average Rating')
plt.show()

plt.savefig("RuntimeVSaveragerating.jpeg", bbox_inches = 'tight')

# %% [markdown]
# Plot above is example, average runtime is 80-120 minutes for most successful films when looking through data.

# %%
# Group data by genre and calculate the mean of the 'ROI' column
mean_ROI_by_genre = master.groupby('genres')['ROI'].mean()

#Get top 20 genres based on mean ROI
top_20_genres = mean_ROI_by_genre.nlargest(20)

# Create a bar chart of the mean ROI by genre
sns.barplot(x=top_20_genres.index, y=top_20_genres.values)
plt.title('Top 20 Genres by Mean ROI')
plt.xlabel('Genres')
plt.ylabel('Mean of ROI')
plt.xticks(rotation=90)
plt.show()

# %%
# Group the data by genre and calculate the median of the 'ROI' column
median_ROI_by_genre = master.groupby('genres')['ROI'].median()

# Get the top 20 genres based on median ROI
top_20_genres_median = median_ROI_by_genre.nlargest(20)

# Create a bar chart of the top 20 genres based on median ROI
sns.barplot(x=top_20_genres_median.index, y=top_20_genres_median.values)
plt.title('Top 20 Genres by Median ROI')
plt.xlabel('Genres')
plt.ylabel('Median of ROI')
plt.xticks(rotation=90)
plt.show()

# %%
# Group the data by genre and calculate the median of the 'ROI' column
mean_ROI_by_runtime = master.groupby('runtime_minutes')['ROI'].mean()

# Get the top 20 genres based on median ROI
#runtime_bin = mean_ROI_by_runtime.nlargest(20)

# Create a bar chart of the top 20 genres based on median ROI
sns.barplot(x=mean_ROI_by_runtime.index, y=mean_ROI_by_runtime.values)
plt.title('Runtime by ROI')
plt.xlabel('Runtime in Min.')
plt.ylabel('Mean of ROI')
plt.xticks(rotation=90)
plt.show()


#################
# Create bins for runtime_minutes
bins = [0, 75, 100, 125, 150, 200, master['runtime_minutes'].max()]
labels = ['0-75', '75-100', '100-125', '125-150', '150-200', '>200']
master['runtime_minutes_bin'] = pd.cut(master['runtime_minutes'], bins=bins, labels=labels)

# Group the data by runtime_minutes_bin and calculate the mean of the 'ROI' column
mean_ROI_by_runtime = master.groupby('runtime_minutes_bin')['ROI'].mean()

# Create a bar chart of runtime_minutes_bin vs mean ROI
sns.barplot(x=mean_ROI_by_runtime.index, y=mean_ROI_by_runtime.values)
plt.title('Mean ROI by runtime_minutes Bin')
plt.xlabel('Runtime Minutes Bin')
plt.ylabel('Mean of ROI')
plt.show()

# %% [markdown]
# sum(profit) by genre and sum(production_budget) by genre then divide the two and do top 20 genre.

# %%
sns.color_palette()
# Out:
# [(0.12156862745098039, 0.4666666666666667, 0.7058823529411765),
#  (1.0, 0.4980392156862745, 0.054901960784313725),
#  (0.17254901960784313, 0.6274509803921569, 0.17254901960784313),
#  (0.8392156862745098, 0.15294117647058825, 0.1568627450980392),
#  (0.5803921568627451, 0.403921568627451, 0.7411764705882353),
#  (0.5490196078431373, 0.33725490196078434, 0.29411764705882354),
#  (0.8901960784313725, 0.4666666666666667, 0.7607843137254902),
#  (0.4980392156862745, 0.4980392156862745, 0.4980392156862745),
#  (0.7372549019607844, 0.7411764705882353, 0.13333333333333333),
#  (0.09019607843137255, 0.7450980392156863, 0.8117647058823529)]

# %%
#Grouped data by genre as well as calculaed the sum of profit and production budget
profit_by_genre = master.groupby('genres')['profit'].sum()
budget_by_genre = master.groupby('genres')['production_budget'].sum()

#Weighted ROI
weighted_roi = profit_by_genre/budget_by_genre


#Top 20 genres from weighted ROI
top_20_genres = weighted_roi.nlargest(20)


#Create barchart of top 20 genres by profit_to_budget_ratio
sns.barplot(x=top_20_genres.index, y=top_20_genres.sort_values()*100, color='green')
plt.title('Top 20 Genres by Weighted ROI')
plt.xlabel('Genres')
plt.ylabel('Weighted ROI')
plt.xticks(rotation=90)
plt.show()

# %%
budget_by_genre[top_20_genres.index]
# Out:
# genres
# Action,Adventure,Sci-Fi       9002600000
# Adventure,Animation,Comedy    6855500000
# Action,Adventure,Fantasy      4645600000
# Action,Adventure,Comedy       2070000000
# Action,Adventure,Animation    1919000000
# Adventure,Family,Fantasy      2085900000
# Action,Crime,Thriller         1271000000
# Action,Adventure,Thriller     1402000000
# Action,Adventure,Drama        2519000000
# Comedy                        1458100000
# Comedy,Romance                 973000000
# Action,Thriller               1029000000
# Action,Comedy,Crime           1200000000
# Drama,Romance                  720800000
# Animation,Comedy,Family        348000000
# Action,Sci-Fi,Thriller         412000000
# Horror,Mystery,Thriller        246000000
# Adventure,Fantasy              695000000
# Biography,Drama,History        509000000
# Adventure,Drama,Fantasy        207500000
# Name: production_budget, dtype: int64

# %%
master.head()
# Out:
#    Unnamed: 0   movie_id                    primary_title  \
# 0          54  tt0359950  The Secret Life of Walter Mitty
# 1          58  tt0365907      A Walk Among the Tombstones
# 2          60  tt0369610                   Jurassic World
# 3          62  tt0376136                    The Rum Diary
# 4          67  tt0383010                The Three Stooges
#
#                     original_title  start_year  runtime_minutes  \
# 0  The Secret Life of Walter Mitty        2013            114.0
# 1      A Walk Among the Tombstones        2014            114.0
# 2                   Jurassic World        2015            124.0
# 3                    The Rum Diary        2011            119.0
# 4                The Three Stooges        2012             92.0
#
#                     genres  averagerating  numvotes  \
# 0   Adventure,Comedy,Drama            7.3  275300.0
# 1       Action,Crime,Drama            6.5  105116.0
# 2  Action,Adventure,Sci-Fi            7.0  539338.0
# 3             Comedy,Drama            6.2   94787.0
# 4            Comedy,Family            5.1   28570.0
#
#                              title studio  domestic_gross_x foreign_gross  \
# 0  The Secret Life of Walter Mitty    Fox        58200000.0     129900000
# 1      A Walk Among the Tombstones   Uni.        26300000.0      26900000
# 2                   Jurassic World   Uni.       652300000.0       1,019.4
# 3                    The Rum Diary     FD        13100000.0      10800000
# 4                The Three Stooges    Fox        44300000.0      10500000
#
#      year    id  release_date                            movie  \
# 0  2013.0  37.0  Dec 25, 2013  The Secret Life of Walter Mitty
# 1  2014.0  67.0  Sep 19, 2014      A Walk Among the Tombstones
# 2  2015.0  34.0  Jun 12, 2015                   Jurassic World
# 3  2011.0  16.0  Oct 28, 2011                    The Rum Diary
# 4  2012.0   4.0  Apr 13, 2012                The Three Stooges
#
#   production_budget domestic_gross_y  worldwide_gross
# 0       $91,000,000      $58,236,838        187861183
# 1       $28,000,000      $26,017,685         62108587
# 2      $215,000,000     $652,270,625       1648854864
# 3       $45,000,000      $13,109,815         21544732
# 4       $30,000,000      $44,338,224         54052249

# %% [markdown]
# ROI = Net income / Cost of investment x 100
